# %%
import pandas as pd

# %%
df = pd.read_csv('full_scrape_1.csv')

# %%
df.shape
# Out:
# (1024524, 4)

# %%
df.head()
# Out:
#                                         Comment Text   Author  \
# 0  Just curious, but what triggered your feelings...  PDXorax
# 1        Christmas time put up a light-up Yang sign!  PDXorax
# 2  During the general election, get in contact wi...  PDXorax
# 3  We need to understand as a country, that the m...  PDXorax
# 4  Part of the reason for this, is because we nee...  PDXorax
#
#             Subreddit  Post ID
# 0  YangForPresidentHQ  ew5ohva
# 1  YangForPresidentHQ  ew5o8vv
# 2  YangForPresidentHQ  ew42bdx
# 3  YangForPresidentHQ  evva7l8
# 4  YangForPresidentHQ  evoo179

# %%
df.dtypes
# Out:
# Comment Text    object
# Author          object
# Subreddit       object
# Post ID         object
# dtype: object

# %%
sum_series = df.groupby(['Author','Subreddit']).size()

# %%
users = list(set([x for x in sum_series.index.get_level_values(0)]))

# %%
len(users)
# Out:
# 1682

# %%
list_of_subs = ['nba','nfl','movies','MMA','CFB','PoliticalHumor','teenagers',
                'soccer','freefolk','gaming','hockey','Libertarian','gameofthrones','MLS',
               ' JoeRogan','conspiracy','marvelstudios','television','asoiaf','leagueoflegends',
                'atheism','samharris','science','fantasyfootball','Cricket','CHIBears','hiphopheads',
                'technology','survivor','canada','Futurology']

# %%
features = {}
political_dict={}
for user in users:
    feature_dict = {}
    for sub in sum_series[user].index:
        if sub in list_of_subs:
            feature_dict[sub]=sum_series[user][sub]
    if len(feature_dict)!=0:
        features[user]=feature_dict
        #create target series
        inner_dict = {}
        try:
            inner_dict['yang'] = sum_series[user]['YangForPresidentHQ']
        except:
            inner_dict['yang'] = 0
        try:
            inner_dict['bernie'] = sum_series[user]['SandersForPresident']
        except:
            inner_dict['bernie'] = 0
        try:
            inner_dict['bernie'] += sum_series[user]['wayofthebern']
        except:
            inner_dict['bernie'] += 0
        try:
            inner_dict['bernie'] += sum_series[user]['Political_Revolution']
        except:
            inner_dict['bernie'] += 0
        try:
            inner_dict['pete'] = sum_series[user]['Pete_Buttigieg']
        except:
            inner_dict['pete'] = 0
        try:
            inner_dict['kamala'] = sum_series[user]['Kamala']
        except:
            inner_dict['kamala'] = 0
        try:
            inner_dict['biden'] = sum_series[user]['JoeBiden']
        except:
            inner_dict['biden'] = 0
        political_dict[user]=inner_dict

# %%
df_feature = pd.DataFrame(features).T

# %%
df_target = pd.DataFrame(political_dict).T

# %%
df_feature.head()
# Out:
#                     CFB  CHIBears  Cricket  Futurology  Libertarian  MLS  MMA  \
# g-m-p-l             NaN       NaN      NaN         NaN          NaN  NaN  NaN
# Maria-Stryker       NaN       NaN      NaN         NaN          NaN  NaN  NaN
# YourphobiaMyfetish  NaN       NaN      NaN         1.0         25.0  NaN  1.0
# shenanakins         NaN       NaN      NaN         NaN          NaN  NaN  NaN
# Picnicpanther       NaN       NaN      NaN         NaN          NaN  NaN  NaN
#
#                     PoliticalHumor  asoiaf  atheism  ...  movies   nba  nfl  \
# g-m-p-l                        NaN     NaN      NaN  ...     NaN  21.0  NaN
# Maria-Stryker                  NaN     NaN      NaN  ...    10.0   NaN  NaN
# YourphobiaMyfetish            13.0     NaN      5.0  ...     NaN   NaN  NaN
# shenanakins                    1.0    84.0      NaN  ...     9.0   NaN  NaN
# Picnicpanther                  NaN     NaN      NaN  ...     1.0   NaN  NaN
#
#                     samharris  science  soccer  survivor  technology  \
# g-m-p-l                   NaN      NaN     NaN       NaN         NaN
# Maria-Stryker             NaN      NaN     NaN       NaN         NaN
# YourphobiaMyfetish        NaN      1.0     NaN       NaN         2.0
# shenanakins               NaN      NaN     NaN       NaN         NaN
# Picnicpanther             NaN      3.0     NaN       NaN         NaN
#
#                     teenagers  television
# g-m-p-l                   NaN         NaN
# Maria-Stryker             NaN         1.0
# YourphobiaMyfetish        1.0         NaN
# shenanakins               NaN        27.0
# Picnicpanther             NaN         3.0
#
# [5 rows x 30 columns]

# %%
df_feature.fillna(0,inplace=True)

# %%
#add code to combine like minded subs
df_feature['got']=df_feature['gameofthrones']+df_feature['asoiaf']
df_feature['soccer_comb']=df_feature['MLS']+df_feature['soccer']
df_feature['football']=df_feature['nfl']+df_feature['CFB']+df_feature['CHIBears']

# %%
#remove above single subs
df_feature.drop(['gameofthrones','asoiaf','soccer','MLS','nfl','CFB','CHIBears'],axis=1,inplace=True)

# %%
df_feature = df_feature.div(df_feature.sum(axis=1), axis=0)

# %%
def func(row):
    total = sum(row)
    if (row['bernie']/total >= .8) & (row['bernie']>=4):
        return 'bernie'
    if (row['biden']/total >= .8) & (row['biden']>=4):
        return 'biden'
    if (row['kamala']/total >= .8) & (row['kamala']>=4):
        return 'kamala'
    if (row['pete']/total >= .8) & (row['pete']>=4):
        return 'pete'
    if (row['yang']/total >= .8) & (row['yang']>=4):
        return 'yang'
    return 'unknown'

# %%
df_target['target'] = df_target.apply(func,axis=1)

# %%
df_target.drop(['bernie','biden','kamala','pete','yang'],axis=1,inplace=True)

# %%
df = pd.concat([df_feature,df_target],axis=1)

# %%
df.shape
# Out:
# (1257, 27)

# %%
df=df[df['target']!='unknown']

# %%
df.shape
# Out:
# (856, 27)

# %%
X = df.drop(['target'],axis=1)

# %%
y = df['target']

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(multi_class='multinomial',solver='lbfgs')

# %%
lr.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr.classes_
# Out:
# array(['bernie', 'biden', 'kamala', 'pete', 'yang'], dtype=object)

# %%
pd.DataFrame(lr.coef_.T,X.columns,lr.classes_)
# Out:
#                    bernie     biden    kamala      pete      yang
# Cricket          0.399621 -0.120657 -0.179974 -0.156862  0.057872
# Futurology      -0.389125 -0.309995 -0.059652 -0.654542  1.413315
# Libertarian     -0.038166 -0.122803 -0.793122 -0.056367  1.010458
# MMA              0.419363 -0.156112  0.671571 -1.146212  0.211389
# PoliticalHumor   0.390003 -0.513123  0.102186  0.033016 -0.012082
# atheism          0.205022  0.260109  0.030927  0.046753 -0.542812
# canada           0.193634 -0.154688  0.108970 -0.512374  0.364458
# conspiracy       1.127402 -0.396142 -0.081730 -0.687306  0.037776
# fantasyfootball -0.006574 -0.139626  0.317642  0.038751 -0.210194
# freefolk         0.108552 -0.581272  0.407091  0.566610 -0.500981
# gaming           0.685603 -0.127604 -0.921604 -0.248448  0.612052
# hiphopheads     -0.273691  0.010621  0.134046 -0.152565  0.281589
# hockey           0.606139 -0.066375 -0.089589  0.107772 -0.557947
# leagueoflegends -0.181317 -0.338593 -0.383220 -0.015506  0.918637
# marvelstudios   -0.042777  0.705636 -0.551411  0.399827 -0.511276
# movies          -0.218914  1.057314 -0.151774  0.428163 -1.114790
# nba              0.041435 -0.671513  0.945809 -0.317135  0.001405
# samharris       -1.231080 -0.018233 -0.259976  0.257469  1.251820
# science         -0.059282  0.231918 -0.330588  0.364778 -0.206827
# survivor        -0.601144  0.473602  0.336908 -0.448924  0.239558
# technology      -0.279043  0.189766  0.020866  0.644631 -0.576221
# teenagers       -0.345878 -0.299614 -0.040918  0.110584  0.575827
# television       0.009902  0.252384 -0.301014  1.041610 -1.002881
# got             -0.246460 -0.463898  0.406520  0.463583 -0.159744
# soccer_comb      0.204675  0.354942  0.254138 -0.409112 -0.404642
# football        -0.474677  0.939507  0.405033  0.302741 -1.172604

# %%
# End of necessary code, code below is just for notes and that one error

# %%
political_dict = {}
for user in users:
    inner_dict = {}
    try:
        inner_dict['yang'] = sum_series[user]['YangForPresidentHQ']
    except:
        inner_dict['yang'] = 0
    try:
        inner_dict['bernie'] = sum_series[user]['SandersForPresident']
    except:
        inner_dict['bernie'] = 0
    try:
        inner_dict['bernie'] += sum_series[user]['wayofthebern']
    except:
        inner_dict['bernie'] += 0
    try:
        inner_dict['bernie'] += sum_series[user]['Political_Revolution']
    except:
        inner_dict['bernie'] += 0
    try:
        inner_dict['pete'] = sum_series[user]['Pete_Buttigieg']
    except:
        inner_dict['pete'] = 0
    try:
        inner_dict['kamala'] = sum_series[user]['Kamala']
    except:
        inner_dict['kamala'] = 0
    try:
        inner_dict['biden'] = sum_series[user]['JoeBiden']
    except:
        inner_dict['biden'] = 0
    political_dict[user]=inner_dict

# %%
df3 = pd.DataFrame(political_dict).T

# %%
df3
# Out:
#                       bernie  biden  kamala  pete  yang
# g-m-p-l                    0      0       0     0   216
# What_A_Do                  0      0       0   223     0
# Maria-Stryker              0      5       0     0     0
# YourphobiaMyfetish         5      0       0     0     2
# shenanakins              191      0       0     0     0
# Picnicpanther             45      0       0     0     0
# Magadad42069              40      0       0     0     0
# GoldenEst82                0      0       0     0    19
# whiskymohawk             102      0       0     0     0
# saethone                   0      0       1    17     0
# aadisaha17                 0      0       0     0    52
# marcus27                   5      0       0    11     0
# Sage1970                   0      0       0     0   383
# YasKhaleesi                0      0       0    19     0
# hahaha_yes                 5      0       0     0     0
# Verification_Expired       0      0       7     0     0
# dizzlesizzle8330           0      0       0     0    76
# aldomendez                 0      0       0     0    48
# Acknowledgerization       73      0       0     0     0
# Bernie_sibling_2020      147      0       0     0     0
# gabriel_oly10              0      0       0     0     1
# Stupidhufflepuff           0      0       0     0    15
# cherrychapstick32          0      0       0    18     0
# bryanlandia               84      0       0     0     0
# Theandric                  0      8       0     0     0
# TheEld                    43      0       0     0     0
# OnMyWurstBehavior          1      0       0     0   153
# TragicallyTired            0      1       0     0     0
# parth3sh                   0      0       0     5    95
# regionalgiant              0      0      16     0     0
# ...                      ...    ...     ...   ...   ...
# Epic_XC                   34      0       0     0     0
# asad1ali2                  0      0       0    48     0
# damotr0n                   0      0       0     0    10
# Wolf_Oak                  22      0       0   207     0
# joshblade                  0      0       0    30     0
# SeriousAffable             0      0       0     2     0
# thajazmaster               0      0       0     0    43
# lifeinprism              172      0      14    19    29
# mumbling_marauder          0      0       0    17     0
# KarmaUK                    0      0       0     0    31
# TokesNotHigh               0      0       0     1     0
# Razer_Man                307      0       0     0     0
# PretteyPretteyGOOD       279      0       0     0     0
# awholenoobworld            3      0       0     0   114
# StrategicNoob17            0      0       0     0     5
# tmtdota                    0      0       0    57     0
# Boloni86                   0      0       0     0   272
# cota1212                   0      2       0     0     0
# andrewtc55               622      0       0     0     0
# Wxze                       0      0       0     0   185
# Sorsly                     2      0       0     0    58
# BlackLeatherRain           0      0       3     0     0
# Tlupa                      0      0       4     0     0
# benadreti                  0      3       0     0     0
# DictaSupreme               0      0       0   701     0
# KittyCatGymnastics         0      4       0     0     0
# huet99                     3      0       0     0     0
# TrumpPooPoosPants          0      0      13     3     0
# enigmaticeducation       177      0       4     0     2
# Anarchymeansihateyou       3      0       0     0     0
#
# [1682 rows x 5 columns]

# %%
df3.shape
# Out:
# (1682, 5)

# %%
def func(row):
    total = sum(row)
    if (row['bernie']/total >= .8) & (row['bernie']>=4):
        return 'bernie'
    if (row['biden']/total >= .8) & (row['biden']>=4):
        return 'biden'
    if (row['kamala']/total >= .8) & (row['kamala']>=4):
        return 'kamala'
    if (row['pete']/total >= .8) & (row['pete']>=4):
        return 'pete'
    if (row['yang']/total >= .8) & (row['yang']>=4):
        return 'yang'
    return 'unknown'

# %%
df3['target'] = df3.apply(func,axis=1)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in long_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in long_scalars
#   import sys
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in long_scalars
#   if __name__ == '__main__':
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in long_scalars
#   # This is added back by InteractiveShellApp.init_path()

# %%
df3['target'].value_counts()
# Out:
# unknown    506
# yang       384
# bernie     372
# pete       283
# kamala      76
# biden       61
# Name: target, dtype: int64

# %%
df3.drop('target',axis=1,inplace=True)
