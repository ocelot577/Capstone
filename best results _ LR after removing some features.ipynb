# %%
import pandas as pd

# %%
df = pd.read_csv('full_scrape_1.csv')

# %%
df.shape
# Out:
# (1024524, 4)

# %%
df.head()
# Out:
#                                         Comment Text   Author  \
# 0  Just curious, but what triggered your feelings...  PDXorax
# 1        Christmas time put up a light-up Yang sign!  PDXorax
# 2  During the general election, get in contact wi...  PDXorax
# 3  We need to understand as a country, that the m...  PDXorax
# 4  Part of the reason for this, is because we nee...  PDXorax
#
#             Subreddit  Post ID
# 0  YangForPresidentHQ  ew5ohva
# 1  YangForPresidentHQ  ew5o8vv
# 2  YangForPresidentHQ  ew42bdx
# 3  YangForPresidentHQ  evva7l8
# 4  YangForPresidentHQ  evoo179

# %%
df.dtypes
# Out:
# Comment Text    object
# Author          object
# Subreddit       object
# Post ID         object
# dtype: object

# %%
sum_series = df.groupby(['Author','Subreddit']).size()

# %%
users = list(set([x for x in sum_series.index.get_level_values(0)]))

# %%
len(users)
# Out:
# 1682

# %%
list_of_subs2 = ['nfl','MMA','CFB','PoliticalHumor','teenagers',
                'soccer','freefolk','gaming','hockey','Libertarian','gameofthrones','MLS',
               ' JoeRogan','conspiracy','marvelstudios','television','asoiaf','leagueoflegends',
                'atheism','samharris','fantasyfootball','CHIBears','hiphopheads',
                'technology','survivor','canada','Futurology','exmormon','Destiny','memes',
                'CryptoCurrency','rupaulsdragrace','Music','dankmemes','stupidpol',
                'Games','FortNiteBR','BigBrother','redsox','baseball','Conservative','Economics',
                'ClashRoyale','DestinyTheGame','europe','NintendoSwitch','IntellectualDarkWeb',
                'askgaybros','hillaryclinton','tuesday','2007scape','tulsi',
                'NASCAR','trees','HistoryMemes','TheSilphRoad','pokemon','Brawlstars','environment','fo76',
                'NYYankees','Android','Overwatch','aznidentity','barstoolsports','wholesomememes',
                'JordanPeterson','TheLastAirbender','golf','DotA2','space','collapse']

# %%
features = {}
political_dict={}
for user in users:
    feature_dict = {}
    for sub in sum_series[user].index:
        if sub in list_of_subs2:
            feature_dict[sub]=sum_series[user][sub]
    if len(feature_dict)!=0:
        features[user]=feature_dict
        #create target series
        inner_dict = {}
        try:
            inner_dict['yang'] = sum_series[user]['YangForPresidentHQ']
        except:
            inner_dict['yang'] = 0
        try:
            inner_dict['bernie'] = sum_series[user]['SandersForPresident']
        except:
            inner_dict['bernie'] = 0
        try:
            inner_dict['bernie'] += sum_series[user]['wayofthebern']
        except:
            inner_dict['bernie'] += 0
        try:
            inner_dict['bernie'] += sum_series[user]['Political_Revolution']
        except:
            inner_dict['bernie'] += 0
        try:
            inner_dict['pete'] = sum_series[user]['Pete_Buttigieg']
        except:
            inner_dict['pete'] = 0
        try:
            inner_dict['kamala'] = sum_series[user]['Kamala']
        except:
            inner_dict['kamala'] = 0
        try:
            inner_dict['biden'] = sum_series[user]['JoeBiden']
        except:
            inner_dict['biden'] = 0
        political_dict[user]=inner_dict

# %%
df_feature = pd.DataFrame(features).T

# %%
df_target = pd.DataFrame(political_dict).T

# %%
def func(row):
    total = sum(row)
    if (row['bernie']/total >= .8) & (row['bernie']>=4):
        return 'bernie'
    if (row['biden']/total >= .8) & (row['biden']>=4):
        return 'biden'
    if (row['kamala']/total >= .8) & (row['kamala']>=4):
        return 'kamala'
    if (row['pete']/total >= .8) & (row['pete']>=4):
        return 'pete'
    if (row['yang']/total >= .8) & (row['yang']>=4):
        return 'yang'
    return 'unknown'

# %%
df_target['target'] = df_target.apply(func,axis=1)
# Out:
# /Users/yichenh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in long_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yichenh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# /Users/yichenh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in long_scalars
#   import sys
# /Users/yichenh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in long_scalars
#   if __name__ == '__main__':
# /Users/yichenh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in long_scalars
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_target.drop(['bernie','biden','kamala','pete','yang'],axis=1,inplace=True)

# %%
df_feature.head()
# Out:
#                      2007scape  Android  BigBrother  Brawlstars  CFB  \
# xenokilla                  NaN      NaN         NaN         NaN  6.0
# 27_Dollar_Lakehouse        NaN      NaN         NaN         NaN  NaN
# 5evenThirty                NaN      NaN         NaN         NaN  NaN
# Khclarkson                 NaN      NaN         NaN         NaN  NaN
# snarkyjoan                 NaN      NaN         NaN         NaN  NaN
#
#                      CHIBears  ClashRoyale  Conservative  CryptoCurrency  \
# xenokilla                 NaN          NaN           NaN             NaN
# 27_Dollar_Lakehouse       NaN          NaN           NaN             NaN
# 5evenThirty               NaN          NaN           NaN             NaN
# Khclarkson                NaN          NaN           NaN             NaN
# snarkyjoan                NaN          NaN           NaN             NaN
#
#                      Destiny  ...  space  stupidpol  survivor  technology  \
# xenokilla                NaN  ...    NaN        NaN       NaN         NaN
# 27_Dollar_Lakehouse      NaN  ...    NaN        NaN       NaN         2.0
# 5evenThirty              NaN  ...    NaN        NaN       NaN         2.0
# Khclarkson               NaN  ...    1.0        NaN       NaN         NaN
# snarkyjoan               NaN  ...    NaN        NaN       NaN         NaN
#
#                      teenagers  television  trees  tuesday  tulsi  \
# xenokilla                  NaN         1.0    NaN      NaN    NaN
# 27_Dollar_Lakehouse        NaN         NaN    NaN      NaN    NaN
# 5evenThirty                NaN         NaN    NaN      NaN    NaN
# Khclarkson                 NaN         NaN    NaN      1.0    NaN
# snarkyjoan                 NaN         NaN    NaN      NaN    NaN
#
#                      wholesomememes
# xenokilla                       NaN
# 27_Dollar_Lakehouse             NaN
# 5evenThirty                     NaN
# Khclarkson                      NaN
# snarkyjoan                      NaN
#
# [5 rows x 71 columns]

# %%
df_feature.fillna(0,inplace=True)

# %%
#add code to combine like minded subs
df_feature['got']=df_feature['gameofthrones']+df_feature['asoiaf']+df_feature['freefolk']
df_feature['soccer_comb']=df_feature['MLS']+df_feature['soccer']
df_feature['football']=df_feature['nfl']+df_feature['CFB']+df_feature['CHIBears']
df_feature['baseball_comb']=df_feature['baseball']+df_feature['redsox']+df_feature['NYYankees']
df_feature['conservative_comb']=df_feature['Conservative']+df_feature['tuesday']
df_feature['games_comb']=df_feature['gaming']+df_feature['Games']
df_feature['memes_comb']=df_feature['memes']+df_feature['dankmemes']+df_feature['HistoryMemes']+df_feature['wholesomememes']
df_feature['pokemon_comb']=df_feature['TheSilphRoad']+df_feature['pokemon']

# %%
#remove above single subs
df_feature.drop(['redsox','baseball','NYYankees','Conservative','tuesday','nfl','CFB','CHIBears','gaming','Games','freefolk','gameofthrones',
                 'asoiaf','memes','dankmemes','HistoryMemes','wholesomememes','TheSilphRoad','pokemon','soccer',
                 'MLS'],axis=1,inplace=True)

# %%
df_feature = df_feature.div(df_feature.sum(axis=1), axis=0)

# %%
df_feature.head(20)
# Out:
#                      2007scape  Android  BigBrother  Brawlstars  ClashRoyale  \
# xenokilla                  0.0  0.00000         0.0         0.0          0.0
# 27_Dollar_Lakehouse        0.0  0.00000         0.0         0.0          0.0
# 5evenThirty                0.0  0.00000         0.0         0.0          0.0
# Khclarkson                 0.0  0.00000         0.0         0.0          0.0
# snarkyjoan                 0.0  0.00000         0.0         0.0          0.0
# Belostoma                  0.0  0.00000         0.0         0.0          0.0
# zThief                     0.0  0.00000         0.0         0.0          0.0
# scarypriest                0.0  0.00000         0.0         0.0          0.0
# Fizzeek                    0.0  0.00000         0.0         0.0          0.0
# autotldr                   0.0  0.00000         0.0         0.0          0.0
# linuxpenguin823            0.0  0.00000         0.0         0.0          0.0
# Eken17                     0.0  0.00000         0.0         0.0          0.0
# Ihaveonequestion           0.0  0.00000         0.0         0.0          0.0
# yourslice                  0.0  0.00000         0.0         0.0          0.0
# yourmomsnutsarehuge        0.0  0.00813         0.0         0.0          0.0
# ubasta                     0.0  0.00000         0.0         0.0          0.0
# Djsoysause                 0.0  0.00000         0.0         0.0          0.0
# sewtheconking              0.0  0.00000         0.0         0.0          0.0
# PotterySucks               0.0  0.00000         0.0         0.0          0.0
# Diimon99                   0.0  0.00000         0.0         0.0          0.0
#
#                      CryptoCurrency  Destiny  DestinyTheGame  DotA2  \
# xenokilla                  0.000000      0.0             0.0    0.0
# 27_Dollar_Lakehouse        0.000000      0.0             0.0    0.0
# 5evenThirty                0.000000      0.0             0.0    0.0
# Khclarkson                 0.000000      0.0             0.0    0.0
# snarkyjoan                 0.000000      0.0             0.0    0.0
# Belostoma                  0.000000      0.0             0.0    0.0
# zThief                     0.000000      0.0             0.0    0.0
# scarypriest                0.000000      0.0             0.0    0.0
# Fizzeek                    0.000000      0.0             0.0    0.0
# autotldr                   0.000000      0.0             0.0    0.0
# linuxpenguin823            0.000000      0.0             0.0    0.0
# Eken17                     0.000000      0.0             0.0    0.0
# Ihaveonequestion           0.000000      0.0             0.0    0.0
# yourslice                  0.303371      0.0             0.0    0.0
# yourmomsnutsarehuge        0.000000      0.0             0.0    0.0
# ubasta                     0.000000      0.0             0.0    0.0
# Djsoysause                 0.000000      0.0             0.0    0.0
# sewtheconking              0.000000      0.0             0.0    0.0
# PotterySucks               0.000000      0.0             0.0    0.0
# Diimon99                   0.000000      0.0             0.0    0.0
#
#                      Economics  ...     trees     tulsi       got  \
# xenokilla             0.000000  ...  0.000000  0.000000  0.000000
# 27_Dollar_Lakehouse   0.000000  ...  0.000000  0.000000  0.673469
# 5evenThirty           0.000000  ...  0.000000  0.000000  0.000000
# Khclarkson            0.004348  ...  0.000000  0.000000  0.000000
# snarkyjoan            0.000000  ...  0.000000  0.000000  0.632653
# Belostoma             0.000000  ...  0.000000  0.000000  0.016438
# zThief                0.000000  ...  0.000000  0.022222  0.022222
# scarypriest           0.000000  ...  0.000000  0.000000  0.000000
# Fizzeek               0.000000  ...  0.000000  0.000000  0.461538
# autotldr              0.000000  ...  0.200000  0.000000  0.000000
# linuxpenguin823       0.000000  ...  0.000000  0.000000  0.029851
# Eken17                0.000000  ...  0.000000  0.000000  0.000000
# Ihaveonequestion      0.000000  ...  0.464286  0.000000  0.035714
# yourslice             0.067416  ...  0.000000  0.000000  0.000000
# yourmomsnutsarehuge   0.000000  ...  0.000000  0.284553  0.000000
# ubasta                0.000000  ...  0.000000  0.000000  0.000000
# Djsoysause            0.109589  ...  0.000000  0.000000  0.000000
# sewtheconking         0.000000  ...  0.000000  0.000000  0.000000
# PotterySucks          0.000000  ...  0.000000  0.000000  0.031250
# Diimon99              0.047619  ...  0.000000  0.000000  0.000000
#
#                      soccer_comb  football  baseball_comb  conservative_comb  \
# xenokilla               0.000000  0.583333       0.000000           0.000000
# 27_Dollar_Lakehouse     0.000000  0.040816       0.000000           0.000000
# 5evenThirty             0.000000  0.000000       0.000000           0.000000
# Khclarkson              0.000000  0.973913       0.000000           0.004348
# snarkyjoan              0.000000  0.000000       0.000000           0.000000
# Belostoma               0.000000  0.101370       0.000000           0.000000
# zThief                  0.000000  0.133333       0.000000           0.288889
# scarypriest             0.000000  0.000000       0.000000           0.000000
# Fizzeek                 0.000000  0.000000       0.000000           0.000000
# autotldr                0.000000  0.000000       0.000000           0.000000
# linuxpenguin823         0.000000  0.000000       0.000000           0.000000
# Eken17                  0.000000  0.000000       0.000000           0.000000
# Ihaveonequestion        0.000000  0.000000       0.000000           0.000000
# yourslice               0.089888  0.044944       0.000000           0.000000
# yourmomsnutsarehuge     0.000000  0.000000       0.000000           0.000000
# ubasta                  0.000000  0.000000       0.000000           0.000000
# Djsoysause              0.000000  0.054795       0.013699           0.013699
# sewtheconking           0.982759  0.008621       0.000000           0.000000
# PotterySucks            0.000000  0.843750       0.000000           0.000000
# Diimon99                0.000000  0.000000       0.000000           0.000000
#
#                      games_comb  memes_comb  pokemon_comb
# xenokilla              0.000000    0.166667      0.000000
# 27_Dollar_Lakehouse    0.000000    0.000000      0.000000
# 5evenThirty            0.333333    0.000000      0.000000
# Khclarkson             0.008696    0.000000      0.004348
# snarkyjoan             0.000000    0.000000      0.000000
# Belostoma              0.000000    0.000000      0.000000
# zThief                 0.155556    0.022222      0.000000
# scarypriest            0.116883    0.000000      0.000000
# Fizzeek                0.076923    0.153846      0.000000
# autotldr               0.000000    0.000000      0.000000
# linuxpenguin823        0.059701    0.000000      0.000000
# Eken17                 0.000000    0.980447      0.000000
# Ihaveonequestion       0.142857    0.000000      0.071429
# yourslice              0.000000    0.000000      0.000000
# yourmomsnutsarehuge    0.000000    0.000000      0.000000
# ubasta                 0.000000    0.000000      0.000000
# Djsoysause             0.000000    0.232877      0.000000
# sewtheconking          0.000000    0.000000      0.000000
# PotterySucks           0.000000    0.000000      0.000000
# Diimon99               0.000000    0.000000      0.000000
#
# [20 rows x 58 columns]

# %%
df = pd.concat([df_feature,df_target],axis=1)

# %%
df.shape
# Out:
# (1348, 59)

# %%
df=df[df['target']!='unknown']

# %%
df.shape
# Out:
# (924, 59)

# %%
X = df.drop(['target'],axis=1)

# %%
y = df['target']

# %%
y.value_counts()
# Out:
# bernie    317
# yang      297
# pete      198
# kamala     63
# biden      49
# Name: target, dtype: int64

# %%
#removing the biden and kamala members since they're counts are really low

# %%
df2 = df[(df['target']!='kamala')&(df['target']!='biden')]

# %%
df2.shape
# Out:
# (812, 59)

# %%
from sklearn.model_selection import train_test_split

# %%
X2 = df2.drop(['target'],axis=1)

# %%
y2 = df2['target']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2,stratify = y2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr2 = LogisticRegression(multi_class='multinomial',solver='lbfgs')

# %%
lr2.fit(X2_train,y2_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr2.score(X2_train,y2_train)
# Out:
# 0.5665024630541872

# %%
lr2.score(X2_test,y2_test)
# Out:
# 0.4630541871921182

# %%
results = pd.DataFrame(lr2.coef_.T,X2.columns,lr2.classes_)

# %%
y2.value_counts(normalize=True)
# Out:
# bernie    0.390394
# yang      0.365764
# pete      0.243842
# Name: target, dtype: float64

# %%
results.head()
# Out:
#                bernie      pete      yang
# 2007scape    0.011420 -0.027024  0.015604
# Android      0.058965 -0.635793  0.576829
# BigBrother   0.512564  0.008357 -0.520921
# Brawlstars  -0.276172 -0.220678  0.496850
# ClashRoyale -0.275342  0.142328  0.133014

# %%
results[(results['bernie']<.25)&(results['pete']<.25)&(results['yang']<.25)]
